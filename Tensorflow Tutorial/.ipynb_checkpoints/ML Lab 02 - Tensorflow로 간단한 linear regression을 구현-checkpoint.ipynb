# %%
import tensorflow as tf

# %%
# X and Y data
x_train = [1, 2, 3]
y_train = [1, 2, 3]

# %%
W = tf.Variable(tf.random.normal([1]), name='weight')
b = tf.Variable(tf.random.normal([1]), name='bias')

# %%
# Our hypothesis XW + b
hypothesis = x_train * W + b

# %%
# cost/Loss function
cost = tf.reduce_mean(tf.square(hypothesis - y_train))

# %%
# Minimize
optimizer = tf.compat.v1.train.GradientDescentOptimizer(learning_rate=0.01)
train = optimizer.minimize(cost)

# %%
# Launch the graph in a session.
sess = tf.compat.v1.Session()
# Initializes global variable in the graph.
sess.run(tf.compat.v1.global_variables_initializer())

# %%
# Fit the line
for step in range(2001):
    sess.run(train)
    if step % 20 == 0:
        print(step, sess.run(cost), sess.run(W), sess.run(b))
# Out:
# 0 25.16127 [-1.3835617] [0.14395425]
# 20 0.35689685 [0.3960226] [0.870754]
# 40 0.12018395 [0.5831917] [0.89968127]
# 60 0.107303806 [0.61789954] [0.8640506]
# 80 0.097438246 [0.63729656] [0.82407665]
# 100 0.08849481 [0.6544794] [0.78540826]
# 120 0.080372386 [0.67073065] [0.74850273]
# 140 0.07299552 [0.6862063] [0.71332645]
# 160 0.06629566 [0.70095354] [0.6798028]
# 180 0.06021082 [0.7150076] [0.6478546]
# 200 0.05468446 [0.7284012] [0.6174079]
# 220 0.049665283 [0.74116534] [0.58839196]
# 240 0.0451068 [0.7533297] [0.5607397]
# 260 0.040966716 [0.7649223] [0.53438693]
# 280 0.037206616 [0.7759701] [0.5092727]
# 300 0.033791635 [0.7864986] [0.48533872]
# 320 0.030690117 [0.7965325] [0.4625296]
# 340 0.027873253 [0.80609465] [0.44079238]
# 360 0.025314929 [0.8152075] [0.4200768]
# 380 0.02299142 [0.82389206] [0.40033472]
# 400 0.020881182 [0.8321685] [0.38152045]
# 420 0.01896463 [0.84005594] [0.36359036]
# 440 0.01722398 [0.8475727] [0.34650296]
# 460 0.015643088 [0.85473627] [0.33021858]
# 480 0.014207297 [0.86156315] [0.31469953]
# 500 0.012903306 [0.8680691] [0.29990983]
# 520 0.011718997 [0.87426937] [0.2858152]
# 540 0.01064337 [0.8801783] [0.27238297]
# 560 0.009666476 [0.8858095] [0.25958198]
# 580 0.00877924 [0.89117604] [0.24738255]
# 600 0.0079734605 [0.8962903] [0.23575647]
# 620 0.007241608 [0.90116435] [0.22467676]
# 640 0.0065769516 [0.9058092] [0.21411778]
# 660 0.005973292 [0.9102359] [0.20405501]
# 680 0.005425041 [0.91445446] [0.19446515]
# 700 0.0049270974 [0.9184748] [0.185326]
# 720 0.0044748676 [0.9223062] [0.17661634]
# 740 0.0040641483 [0.9259575] [0.16831602]
# 760 0.0036911292 [0.9294372] [0.16040581]
# 780 0.003352348 [0.93275344] [0.15286732]
# 800 0.0030446535 [0.9359138] [0.14568311]
# 820 0.0027652031 [0.9389255] [0.13883656]
# 840 0.0025113972 [0.9417958] [0.13231172]
# 860 0.002280893 [0.9445312] [0.12609355]
# 880 0.0020715436 [0.947138] [0.12016764]
# 900 0.0018814099 [0.9496224] [0.11452023]
# 920 0.0017087254 [0.95198995] [0.1091382]
# 940 0.0015518944 [0.9542462] [0.10400909]
# 960 0.0014094565 [0.95639646] [0.09912105]
